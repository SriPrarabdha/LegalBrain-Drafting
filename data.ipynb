# %%
import os
fileStruct = []
t = os.listdir(os.getcwd())

t0 = os.listdir(os.getcwd()+'/'+t[0])
for i in range((len(t0))):
    t1 = os.listdir(os.getcwd()+'/'+t[0]+'/' + t0[i])
    folder = {t0[i]:t1}
    fileStruct.append(folder)

fileStruct
# Out:
# [{'Acknowledgement': ['ACKNOWLEDGEMENTS',
#    'acknowledgment by advocates.rtf',
#    'acknowledgment by agent.rtf',
#    'acknowledgment.rtf',
#    'Form 1.rtf',
#    'Form 2.rtf',
#    'Form 3.rtf',
#    'Form 4.rtf',
#    'Form 5.rtf',
#    'Form 6.rtf',
#    'Form 7.rtf',
#    'Form 8.rtf',
#    'Form 9.rtf']},
#  {'Adoption': ['Adoption by a hindu without his wife_s consent.rtf',
#    'Adoption deed by a hindu widow.rtf',
#    'ADOPTION DEED FOR THE ADOPTION OF A MAJOR SON.rtf',
#    'ADOPTION FROM A GUARDIAN OF A CHILD.rtf',
#    'ADOPTION OF AN ORPHAN FROM AN ORPHANAGE.rtf',
#    'ADOPTION WITH A SETTLEMENT OF PROPERTY OF ADOPTING PARTY.rtf',
#    'AGREEMENT TO ADOPT A SON BETWEEN A WIDOW, NATURAL FATHER OF SON TO BE ADOPTED AND THE INTENDED SON TO BE ADOPTED.rtf',
#    'AUTHORITY BY HUSBAND TO TAKE IN ADOPTION.rtf',
#    'CERTIFICATE BY THE SUPERINTENDENT OF ORPHANAGE.rtf',
#    'CONSENT BY WIFE TO ADOPT A SON.rtf',
# ...

# %%
list(fileStruct[0].items())[0][1]
# Out:
# ['ACKNOWLEDGEMENTS',
#  'acknowledgment by advocates.rtf',
#  'acknowledgment by agent.rtf',
#  'acknowledgment.rtf',
#  'Form 1.rtf',
#  'Form 2.rtf',
#  'Form 3.rtf',
#  'Form 4.rtf',
#  'Form 5.rtf',
#  'Form 6.rtf',
#  'Form 7.rtf',
#  'Form 8.rtf',
#  'Form 9.rtf']

# %%
rtfFiles = []
